# %%
#Lab01
from __future__ import print_function, division

# %matplotlib inline

import thinkdsp
import thinkplot

import numpy as np

from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from IPython.display import display


sin_sig = thinkdsp.SinSignal(freq=7008, amp=8, offset=0)
sin_sig.plot()
thinkplot.config(xlabel='Time (s)')

# %%
#Lab02
signal = thinkdsp.TriangleSignal(8)
duration = signal.period*80
segment = signal.make_wave(duration, framerate=10000)
segment.plot()
beamwave = signal.make_wave(duration, framerate=10000)
beamwave.apodize()
beamwave.make_audio()
spectrum = beamwave.make_spectrum()
spectrum.plot()

# %%
signal = thinkdsp.SawtoothSignal(freq)
    wave = signal.make_wave(duration=0.5, framerate=framerate)
    spectrum = wave.make_spectrum()

# %%
#Lab03
signal = thinkdsp.SquareSignal(8)
duration = signal.period*80
segment = signal.make_wave(duration, framerate=10000)
segment.plot()
